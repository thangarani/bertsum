# %% [markdown]
# <a href="https://colab.research.google.com/github/thangarani/bertsum/blob/master/Copy_of_TextSummarization_bertsum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/nlpyang/BertSum.git

# %%
cd /content/BertSum/

# %%
# !git clone https://github.com/thangarani/raw_stories.git

# %%
# !wget http://nlp.stanford.edu/software/stanford-corenlp-latest.zip

# %%
pwd

# %%
# !pip3 install pytorch_pretrained_bert

# %%
# !pip install tensorboardX

# %%
# !pip install multiprocess

# %%
# !sudo apt install unzip
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# unzip is already the newest version (6.0-21ubuntu1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 33 not upgraded.

# %%
cd /content/BertSum/
# Out:
# /content/BertSum

# %%
# !unzip stanford-corenlp-latest.zip

# %%
# !git clone https://github.com/andersjo/pyrouge.git

# %%
cd pyrouge/tools/ROUGE-1.5.5

# %%
pip install perl

# %%
# !export ROUGE_EVAL_HOME="/contents/pyrouge/tools/ROUGE-1.5.5/data/"

# %%
cd data/WordNet-2.0-Exceptions/

# %%
# !apt-get install synaptic

# %%
# !./buildExeptionDB.pl . exc WordNet-2.0.exc.db

# %%
cd ../

# %%
# !ln -s WordNet-2.0-Exceptions/WordNet-2.0.exc.db WordNet-2.0.exc.db

# %%
ls

# %%
rm WordNet-2.0.exc.db

# %%
# !ln -s WordNet-2.0-Exceptions/WordNet-2.0.exc.db WordNet-2.0.exc.db

# %%
# !apt-get install libxml-dom-perl

# %%
# !git clone https://github.com/bheinzerling/pyrouge.git

# %%
cd pyrouge

# %%
# !python setup.py install

# %%
# !pyrouge_set_rouge_path /content/BertSum/pyrouge/tools/ROUGE-1.5.5/

# %%
# !python -m pyrouge.test

# %%
cd

# %%
cd /content/BertSum/src/

# %% [markdown]
# File "/content/BertSum/src/models/data_loader.py", line 31, in __init__
#     mask = 1 - (src == 0) -> change -> mask = ~ ( src == 0 )

# %%
cd /content/BertSum

# %%
mkdir merged_stories_tokenized

# %%
cd /content/BertSum/src/
# Out:
# /content/BertSum/src

# %%
# !jar -tvf /content/BertSum/stanford-corenlp-4.0.0/stanford-corenlp-4.0.0.jar

# %%
# %env CLASSPATH=/content/BertSum/stanford-corenlp-4.0.0/stanford-corenlp-4.0.0.jar
# Out:
# env: CLASSPATH=/content/BertSum/stanford-corenlp-4.0.0/stanford-corenlp-4.0.0.jar

# %%
env

# %%
# !python preprocess.py -mode tokenize -raw_path ../raw_stories -save_path ../merged_stories_tokenized -log_file ../logs/cnndm.log
# Out:
# Streaming output truncated to the last 5000 lines.
# Processing file /content/BertSum/raw_stories/0b8604027609fb7a4a6432e6a5e903e10a1df91c.story ... writing to /content/BertSum/merged_stories_tokenized/0b8604027609fb7a4a6432e6a5e903e10a1df91c.story.json
# Annotating file /content/BertSum/raw_stories/0b8604027609fb7a4a6432e6a5e903e10a1df91c.story ... done [0.0 sec].
# Processing file /content/BertSum/raw_stories/b0f2632ea8866a8d4c40b93c655232b7dec4972a.story ... writing to /content/BertSum/merged_stories_tokenized/b0f2632ea8866a8d4c40b93c655232b7dec4972a.story.json
# Annotating file /content/BertSum/raw_stories/b0f2632ea8866a8d4c40b93c655232b7dec4972a.story ... done [0.0 sec].
# Processing file /content/BertSum/raw_stories/3fe50f8a7a03e0aece313cebd69583fd43153d01.story ... writing to /content/BertSum/merged_stories_tokenized/3fe50f8a7a03e0aece313cebd69583fd43153d01.story.json
# ...

# %%
cd /content/BertSum/merged_stories_tokenized/
# Out:
# /content/BertSum/merged_stories_tokenized

# %%
# !ls | wc -l
# Out:
# 162237

# %%
# !python train.py -mode train -encoder rnn -dropout 0.1 -bert_data_path ../bert_data/cnndm -model_path ../models/bert_rnn -lr 2e-3 -visible_gpus 0,1,2 -gpu_ranks 0,1,2 -world_size 1 -report_every 2000 -save_checkpoint_steps 20000 -batch_size 3000 -decay_method noam -train_steps 40000 -accum_count 2 -log_file ../logs/bert_rnn -use_interval true -warmup_steps 10000 -rnn_size 768 -dropout 0.1

# %%
# !df -h .
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay          69G   32G   34G  49% /

# %%
# !df -h .
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         108G   32G   71G  31% /
